# %% [markdown]
# **Google Drive Mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Load packages**

# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec

# %% [markdown]
# Now, We need to prepare our data to feed into the model. There is a builtin method in [Keras](https://keras.io/preprocessing/image/) that can extract your images from folders.
#
# Following is the gernalized function used to extract data from the directory.

# %%
def get_images(directory):
    Images = []
    Labels = []  
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'Normal': 
            label = 0
        elif labels == 'COVID-19':
            label = 1 
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

def get_classlabel(class_code):
    labels = {0:'Normal', 1:'COVID-19'}
    return labels[class_code]

# %%
Images, Labels = get_images('/content/drive/MyDrive/Radiology_workshop_monjoy/classification/data/') #Extract the training images from the folders.

Images = np.array(Images) #converting the list of images to numpy array.
Labels = np.array(Labels)

# %%
Labels
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
Images.shape
# Out:
# (1684, 150, 150, 3)

# %% [markdown]
# Lets find shape of our traing data.
#
# As you see, The Training data is in shape of (Number of Training Images, Width of image, Height of image, Channel of image). This shape is very important. If you didnot resize the images to same size. It should be (No. of images,) shape. So, using this shape you cant feed the images to the model.

# %%
print("Shape of Images:",Images.shape)
print("Shape of Labels:",Labels.shape)
# Out:
# Shape of Images: (1684, 150, 150, 3)
# Shape of Labels: (1684,)

# %% [markdown]
# Let us look some random images of our dataset.

# %%
f,ax = plot.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images))
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')

# %% [markdown]
# Now, Create the CNN model to predict the class labels.This is the basic CNN model.

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(1,activation='sigmoid'))

model.compile(optimizer=Optimizer.Adam(lr=0.0001),loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
SVG(model_to_dot(model).create(prog='dot', format='svg'))
Utils.plot_model(model,to_file='model.png',show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 200)     5600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 146, 146, 180)     324180
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 29, 29, 180)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 180)       291780
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 140)       226940
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 100)       126100
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 21, 21, 50)        45050
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 180)               144180
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               18100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 1,187,031
# Trainable params: 1,187,031
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, lets train the model with validation split equal to 30% from training data. Validation split is used to determine that our model is not geting over-fitted.

# %%
import tensorflow as tf
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "./output/cp_NEW-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights every 1 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    period=1)

# Save the weights using the `checkpoint_path` format
model.save_weights(checkpoint_path.format(epoch=0))

# Train the model with the new callback
trained = model.fit(Images,Labels,epochs=100,callbacks=[cp_callback],validation_split=0.30, verbose=1) #verbose meaning using or expressed in more words than are needed.
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 37/37 [==============================] - 12s 212ms/step - loss: 1.1311 - accuracy: 0.5202 - val_loss: 0.6945 - val_accuracy: 0.5079
#
# Epoch 00001: saving model to ./output/cp_NEW-0001.ckpt
# Epoch 2/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.7085 - accuracy: 0.5041 - val_loss: 0.6770 - val_accuracy: 0.5968
#
# Epoch 00002: saving model to ./output/cp_NEW-0002.ckpt
# Epoch 3/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.6818 - accuracy: 0.5968 - val_loss: 0.7094 - val_accuracy: 0.4466
#
# Epoch 00003: saving model to ./output/cp_NEW-0003.ckpt
# Epoch 4/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.6903 - accuracy: 0.5628 - val_loss: 0.6497 - val_accuracy: 0.6107
#
# Epoch 00004: saving model to ./output/cp_NEW-0004.ckpt
# Epoch 5/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.6614 - accuracy: 0.5899 - val_loss: 0.6214 - val_accuracy: 0.6344
#
# Epoch 00005: saving model to ./output/cp_NEW-0005.ckpt
# Epoch 6/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.6415 - accuracy: 0.6067 - val_loss: 0.6185 - val_accuracy: 0.6462
#
# Epoch 00006: saving model to ./output/cp_NEW-0006.ckpt
# Epoch 7/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.6566 - accuracy: 0.5984 - val_loss: 0.6497 - val_accuracy: 0.6581
#
# Epoch 00007: saving model to ./output/cp_NEW-0007.ckpt
# Epoch 8/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.6607 - accuracy: 0.5856 - val_loss: 0.5817 - val_accuracy: 0.7075
#
# Epoch 00008: saving model to ./output/cp_NEW-0008.ckpt
# Epoch 9/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.6126 - accuracy: 0.6502 - val_loss: 0.5709 - val_accuracy: 0.6976
#
# Epoch 00009: saving model to ./output/cp_NEW-0009.ckpt
# Epoch 10/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.5985 - accuracy: 0.6551 - val_loss: 0.5176 - val_accuracy: 0.7233
#
# Epoch 00010: saving model to ./output/cp_NEW-0010.ckpt
# Epoch 11/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.5310 - accuracy: 0.7342 - val_loss: 0.5415 - val_accuracy: 0.7727
#
# Epoch 00011: saving model to ./output/cp_NEW-0011.ckpt
# Epoch 12/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.5343 - accuracy: 0.7316 - val_loss: 0.4425 - val_accuracy: 0.8043
#
# Epoch 00012: saving model to ./output/cp_NEW-0012.ckpt
# Epoch 13/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.4791 - accuracy: 0.7820 - val_loss: 0.4707 - val_accuracy: 0.7688
#
# Epoch 00013: saving model to ./output/cp_NEW-0013.ckpt
# Epoch 14/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.4808 - accuracy: 0.7669 - val_loss: 0.4391 - val_accuracy: 0.7866
#
# Epoch 00014: saving model to ./output/cp_NEW-0014.ckpt
# Epoch 15/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.3620 - accuracy: 0.8396 - val_loss: 0.3613 - val_accuracy: 0.8439
#
# Epoch 00015: saving model to ./output/cp_NEW-0015.ckpt
# Epoch 16/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.3425 - accuracy: 0.8496 - val_loss: 0.3428 - val_accuracy: 0.8419
#
# Epoch 00016: saving model to ./output/cp_NEW-0016.ckpt
# Epoch 17/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.3142 - accuracy: 0.8587 - val_loss: 0.2718 - val_accuracy: 0.8696
#
# Epoch 00017: saving model to ./output/cp_NEW-0017.ckpt
# Epoch 18/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2376 - accuracy: 0.9112 - val_loss: 0.2159 - val_accuracy: 0.9150
#
# Epoch 00018: saving model to ./output/cp_NEW-0018.ckpt
# Epoch 19/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2163 - accuracy: 0.9187 - val_loss: 0.1843 - val_accuracy: 0.9269
#
# Epoch 00019: saving model to ./output/cp_NEW-0019.ckpt
# Epoch 20/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.1510 - accuracy: 0.9495 - val_loss: 0.2249 - val_accuracy: 0.9032
#
# Epoch 00020: saving model to ./output/cp_NEW-0020.ckpt
# Epoch 21/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.1513 - accuracy: 0.9490 - val_loss: 0.1646 - val_accuracy: 0.9368
#
# Epoch 00021: saving model to ./output/cp_NEW-0021.ckpt
# Epoch 22/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.1906 - accuracy: 0.9302 - val_loss: 0.1477 - val_accuracy: 0.9506
#
# Epoch 00022: saving model to ./output/cp_NEW-0022.ckpt
# Epoch 23/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.1120 - accuracy: 0.9620 - val_loss: 0.1100 - val_accuracy: 0.9585
#
# Epoch 00023: saving model to ./output/cp_NEW-0023.ckpt
# Epoch 24/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0849 - accuracy: 0.9737 - val_loss: 0.1064 - val_accuracy: 0.9684
#
# Epoch 00024: saving model to ./output/cp_NEW-0024.ckpt
# Epoch 25/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0679 - accuracy: 0.9820 - val_loss: 0.1506 - val_accuracy: 0.9466
#
# Epoch 00025: saving model to ./output/cp_NEW-0025.ckpt
# Epoch 26/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.1071 - accuracy: 0.9666 - val_loss: 0.1534 - val_accuracy: 0.9447
#
# Epoch 00026: saving model to ./output/cp_NEW-0026.ckpt
# Epoch 27/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0702 - accuracy: 0.9838 - val_loss: 0.1148 - val_accuracy: 0.9605
#
# Epoch 00027: saving model to ./output/cp_NEW-0027.ckpt
# Epoch 28/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0468 - accuracy: 0.9854 - val_loss: 0.0880 - val_accuracy: 0.9684
#
# Epoch 00028: saving model to ./output/cp_NEW-0028.ckpt
# Epoch 29/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0268 - accuracy: 0.9943 - val_loss: 0.1351 - val_accuracy: 0.9545
#
# Epoch 00029: saving model to ./output/cp_NEW-0029.ckpt
# Epoch 30/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0214 - accuracy: 0.9952 - val_loss: 0.0900 - val_accuracy: 0.9704
#
# Epoch 00030: saving model to ./output/cp_NEW-0030.ckpt
# Epoch 31/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0334 - accuracy: 0.9914 - val_loss: 0.1156 - val_accuracy: 0.9625
#
# Epoch 00031: saving model to ./output/cp_NEW-0031.ckpt
# Epoch 32/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0450 - accuracy: 0.9848 - val_loss: 0.0892 - val_accuracy: 0.9684
#
# Epoch 00032: saving model to ./output/cp_NEW-0032.ckpt
# Epoch 33/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0179 - accuracy: 0.9982 - val_loss: 0.1324 - val_accuracy: 0.9585
#
# Epoch 00033: saving model to ./output/cp_NEW-0033.ckpt
# Epoch 34/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9723
#
# Epoch 00034: saving model to ./output/cp_NEW-0034.ckpt
# Epoch 35/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0106 - accuracy: 0.9988 - val_loss: 0.1032 - val_accuracy: 0.9644
#
# Epoch 00035: saving model to ./output/cp_NEW-0035.ckpt
# Epoch 36/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0086 - accuracy: 0.9985 - val_loss: 0.0972 - val_accuracy: 0.9743
#
# Epoch 00036: saving model to ./output/cp_NEW-0036.ckpt
# Epoch 37/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9723
#
# Epoch 00037: saving model to ./output/cp_NEW-0037.ckpt
# Epoch 38/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 0.9763
#
# Epoch 00038: saving model to ./output/cp_NEW-0038.ckpt
# Epoch 39/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.1412 - val_accuracy: 0.9644
#
# Epoch 00039: saving model to ./output/cp_NEW-0039.ckpt
# Epoch 40/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0633 - accuracy: 0.9808 - val_loss: 0.1071 - val_accuracy: 0.9664
#
# Epoch 00040: saving model to ./output/cp_NEW-0040.ckpt
# Epoch 41/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0309 - accuracy: 0.9874 - val_loss: 0.0904 - val_accuracy: 0.9704
#
# Epoch 00041: saving model to ./output/cp_NEW-0041.ckpt
# Epoch 42/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0189 - accuracy: 0.9938 - val_loss: 0.0858 - val_accuracy: 0.9664
#
# Epoch 00042: saving model to ./output/cp_NEW-0042.ckpt
# Epoch 43/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0816 - accuracy: 0.9739 - val_loss: 0.1311 - val_accuracy: 0.9526
#
# Epoch 00043: saving model to ./output/cp_NEW-0043.ckpt
# Epoch 44/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0363 - accuracy: 0.9923 - val_loss: 0.0913 - val_accuracy: 0.9644
#
# Epoch 00044: saving model to ./output/cp_NEW-0044.ckpt
# Epoch 45/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9723
#
# Epoch 00045: saving model to ./output/cp_NEW-0045.ckpt
# Epoch 46/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9763
#
# Epoch 00046: saving model to ./output/cp_NEW-0046.ckpt
# Epoch 47/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.0989 - val_accuracy: 0.9684
#
# Epoch 00047: saving model to ./output/cp_NEW-0047.ckpt
# Epoch 48/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9704
#
# Epoch 00048: saving model to ./output/cp_NEW-0048.ckpt
# Epoch 49/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9723
#
# Epoch 00049: saving model to ./output/cp_NEW-0049.ckpt
# Epoch 50/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9763
#
# Epoch 00050: saving model to ./output/cp_NEW-0050.ckpt
# Epoch 51/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0807 - val_accuracy: 0.9743
#
# Epoch 00051: saving model to ./output/cp_NEW-0051.ckpt
# Epoch 52/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0037 - accuracy: 0.9973 - val_loss: 0.0721 - val_accuracy: 0.9763
#
# Epoch 00052: saving model to ./output/cp_NEW-0052.ckpt
# Epoch 53/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9723
#
# Epoch 00053: saving model to ./output/cp_NEW-0053.ckpt
# Epoch 54/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0068 - accuracy: 0.9968 - val_loss: 0.0860 - val_accuracy: 0.9743
#
# Epoch 00054: saving model to ./output/cp_NEW-0054.ckpt
# Epoch 55/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9723
#
# Epoch 00055: saving model to ./output/cp_NEW-0055.ckpt
# Epoch 56/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9723
#
# Epoch 00056: saving model to ./output/cp_NEW-0056.ckpt
# Epoch 57/100
# 37/37 [==============================] - 5s 138ms/step - loss: 6.0308e-04 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9723
#
# Epoch 00057: saving model to ./output/cp_NEW-0057.ckpt
# Epoch 58/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9763
#
# Epoch 00058: saving model to ./output/cp_NEW-0058.ckpt
# Epoch 59/100
# 37/37 [==============================] - 5s 139ms/step - loss: 8.8969e-04 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9763
#
# Epoch 00059: saving model to ./output/cp_NEW-0059.ckpt
# Epoch 60/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0048 - accuracy: 0.9974 - val_loss: 0.1183 - val_accuracy: 0.9545
#
# Epoch 00060: saving model to ./output/cp_NEW-0060.ckpt
# Epoch 61/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.1623 - accuracy: 0.9511 - val_loss: 0.2869 - val_accuracy: 0.8874
#
# Epoch 00061: saving model to ./output/cp_NEW-0061.ckpt
# Epoch 62/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2077 - accuracy: 0.9060 - val_loss: 0.0858 - val_accuracy: 0.9743
#
# Epoch 00062: saving model to ./output/cp_NEW-0062.ckpt
# Epoch 63/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0387 - accuracy: 0.9881 - val_loss: 0.0793 - val_accuracy: 0.9743
#
# Epoch 00063: saving model to ./output/cp_NEW-0063.ckpt
# Epoch 64/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.0663 - val_accuracy: 0.9802
#
# Epoch 00064: saving model to ./output/cp_NEW-0064.ckpt
# Epoch 65/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0078 - accuracy: 0.9999 - val_loss: 0.0847 - val_accuracy: 0.9822
#
# Epoch 00065: saving model to ./output/cp_NEW-0065.ckpt
# Epoch 66/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0038 - accuracy: 0.9999 - val_loss: 0.0941 - val_accuracy: 0.9763
#
# Epoch 00066: saving model to ./output/cp_NEW-0066.ckpt
# Epoch 67/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9763
#
# Epoch 00067: saving model to ./output/cp_NEW-0067.ckpt
# Epoch 68/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.1076 - val_accuracy: 0.9664
#
# Epoch 00068: saving model to ./output/cp_NEW-0068.ckpt
# Epoch 69/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.1199 - val_accuracy: 0.9684
#
# Epoch 00069: saving model to ./output/cp_NEW-0069.ckpt
# Epoch 70/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0069 - accuracy: 0.9989 - val_loss: 0.1134 - val_accuracy: 0.9704
#
# Epoch 00070: saving model to ./output/cp_NEW-0070.ckpt
# Epoch 71/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0133 - accuracy: 0.9942 - val_loss: 0.1059 - val_accuracy: 0.9743
#
# Epoch 00071: saving model to ./output/cp_NEW-0071.ckpt
# Epoch 72/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.1070 - val_accuracy: 0.9723
#
# Epoch 00072: saving model to ./output/cp_NEW-0072.ckpt
# Epoch 73/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.9743
#
# Epoch 00073: saving model to ./output/cp_NEW-0073.ckpt
# Epoch 74/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9704
#
# Epoch 00074: saving model to ./output/cp_NEW-0074.ckpt
# Epoch 75/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9743
#
# Epoch 00075: saving model to ./output/cp_NEW-0075.ckpt
# Epoch 76/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.1064 - val_accuracy: 0.9704
#
# Epoch 00076: saving model to ./output/cp_NEW-0076.ckpt
# Epoch 77/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9783
#
# Epoch 00077: saving model to ./output/cp_NEW-0077.ckpt
# Epoch 78/100
# 37/37 [==============================] - 5s 137ms/step - loss: 5.7642e-04 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9802
#
# Epoch 00078: saving model to ./output/cp_NEW-0078.ckpt
# Epoch 79/100
# 37/37 [==============================] - 5s 139ms/step - loss: 8.7929e-04 - accuracy: 0.9997 - val_loss: 0.1058 - val_accuracy: 0.9783
#
# Epoch 00079: saving model to ./output/cp_NEW-0079.ckpt
# Epoch 80/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9783
#
# Epoch 00080: saving model to ./output/cp_NEW-0080.ckpt
# Epoch 81/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0860 - val_accuracy: 0.9743
#
# Epoch 00081: saving model to ./output/cp_NEW-0081.ckpt
# Epoch 82/100
# 37/37 [==============================] - 5s 139ms/step - loss: 9.1013e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9802
#
# Epoch 00082: saving model to ./output/cp_NEW-0082.ckpt
# Epoch 83/100
# 37/37 [==============================] - 5s 140ms/step - loss: 9.2741e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9763
#
# Epoch 00083: saving model to ./output/cp_NEW-0083.ckpt
# Epoch 84/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9783
#
# Epoch 00084: saving model to ./output/cp_NEW-0084.ckpt
# Epoch 85/100
# 37/37 [==============================] - 5s 138ms/step - loss: 5.7196e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9743
#
# Epoch 00085: saving model to ./output/cp_NEW-0085.ckpt
# Epoch 86/100
# 37/37 [==============================] - 5s 140ms/step - loss: 8.7178e-04 - accuracy: 0.9999 - val_loss: 0.0726 - val_accuracy: 0.9802
#
# Epoch 00086: saving model to ./output/cp_NEW-0086.ckpt
# Epoch 87/100
# 37/37 [==============================] - 5s 138ms/step - loss: 7.7083e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9802
#
# Epoch 00087: saving model to ./output/cp_NEW-0087.ckpt
# Epoch 88/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9763
#
# Epoch 00088: saving model to ./output/cp_NEW-0088.ckpt
# Epoch 89/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0785 - val_accuracy: 0.9802
#
# Epoch 00089: saving model to ./output/cp_NEW-0089.ckpt
# Epoch 90/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9723
#
# Epoch 00090: saving model to ./output/cp_NEW-0090.ckpt
# Epoch 91/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.0911 - val_accuracy: 0.9763
#
# Epoch 00091: saving model to ./output/cp_NEW-0091.ckpt
# Epoch 92/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.2781 - val_accuracy: 0.9447
#
# Epoch 00092: saving model to ./output/cp_NEW-0092.ckpt
# Epoch 93/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0231 - accuracy: 0.9920 - val_loss: 0.0911 - val_accuracy: 0.9704
#
# Epoch 00093: saving model to ./output/cp_NEW-0093.ckpt
# Epoch 94/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0413 - accuracy: 0.9885 - val_loss: 0.0712 - val_accuracy: 0.9704
#
# Epoch 00094: saving model to ./output/cp_NEW-0094.ckpt
# Epoch 95/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0521 - accuracy: 0.9764 - val_loss: 0.0957 - val_accuracy: 0.9684
#
# Epoch 00095: saving model to ./output/cp_NEW-0095.ckpt
# Epoch 96/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0330 - accuracy: 0.9879 - val_loss: 0.0977 - val_accuracy: 0.9644
#
# Epoch 00096: saving model to ./output/cp_NEW-0096.ckpt
# Epoch 97/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.0836 - val_accuracy: 0.9802
#
# Epoch 00097: saving model to ./output/cp_NEW-0097.ckpt
# Epoch 98/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.9822
#
# Epoch 00098: saving model to ./output/cp_NEW-0098.ckpt
# Epoch 99/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9783
#
# Epoch 00099: saving model to ./output/cp_NEW-0099.ckpt
# Epoch 100/100
# 37/37 [==============================] - 5s 140ms/step - loss: 7.5314e-04 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 0.9783
#
# Epoch 00100: saving model to ./output/cp_NEW-0100.ckpt

# %%
# !ls {checkpoint_dir}
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# checkpoint			      cp_NEW-0050.ckpt.index
# cp_NEW-0000.ckpt.data-00000-of-00001  cp_NEW-0051.ckpt.data-00000-of-00001
# cp_NEW-0000.ckpt.index		      cp_NEW-0051.ckpt.index
# cp_NEW-0001.ckpt.data-00000-of-00001  cp_NEW-0052.ckpt.data-00000-of-00001
# cp_NEW-0001.ckpt.index		      cp_NEW-0052.ckpt.index
# cp_NEW-0002.ckpt.data-00000-of-00001  cp_NEW-0053.ckpt.data-00000-of-00001
# cp_NEW-0002.ckpt.index		      cp_NEW-0053.ckpt.index
# cp_NEW-0003.ckpt.data-00000-of-00001  cp_NEW-0054.ckpt.data-00000-of-00001
# cp_NEW-0003.ckpt.index		      cp_NEW-0054.ckpt.index
# cp_NEW-0004.ckpt.data-00000-of-00001  cp_NEW-0055.ckpt.data-00000-of-00001
# cp_NEW-0004.ckpt.index		      cp_NEW-0055.ckpt.index
# cp_NEW-0005.ckpt.data-00000-of-00001  cp_NEW-0056.ckpt.data-00000-of-00001
# cp_NEW-0005.ckpt.index		      cp_NEW-0056.ckpt.index
# cp_NEW-0006.ckpt.data-00000-of-00001  cp_NEW-0057.ckpt.data-00000-of-00001
# cp_NEW-0006.ckpt.index		      cp_NEW-0057.ckpt.index
# cp_NEW-0007.ckpt.data-00000-of-00001  cp_NEW-0058.ckpt.data-00000-of-00001
# cp_NEW-0007.ckpt.index		      cp_NEW-0058.ckpt.index
# cp_NEW-0008.ckpt.data-00000-of-00001  cp_NEW-0059.ckpt.data-00000-of-00001
# cp_NEW-0008.ckpt.index		      cp_NEW-0059.ckpt.index
# cp_NEW-0009.ckpt.data-00000-of-00001  cp_NEW-0060.ckpt.data-00000-of-00001
# cp_NEW-0009.ckpt.index		      cp_NEW-0060.ckpt.index
# cp_NEW-0010.ckpt.data-00000-of-00001  cp_NEW-0061.ckpt.data-00000-of-00001
# cp_NEW-0010.ckpt.index		      cp_NEW-0061.ckpt.index
# cp_NEW-0011.ckpt.data-00000-of-00001  cp_NEW-0062.ckpt.data-00000-of-00001
# cp_NEW-0011.ckpt.index		      cp_NEW-0062.ckpt.index
# cp_NEW-0012.ckpt.data-00000-of-00001  cp_NEW-0063.ckpt.data-00000-of-00001
# cp_NEW-0012.ckpt.index		      cp_NEW-0063.ckpt.index
# cp_NEW-0013.ckpt.data-00000-of-00001  cp_NEW-0064.ckpt.data-00000-of-00001
# cp_NEW-0013.ckpt.index		      cp_NEW-0064.ckpt.index
# cp_NEW-0014.ckpt.data-00000-of-00001  cp_NEW-0065.ckpt.data-00000-of-00001
# cp_NEW-0014.ckpt.index		      cp_NEW-0065.ckpt.index
# cp_NEW-0015.ckpt.data-00000-of-00001  cp_NEW-0066.ckpt.data-00000-of-00001
# cp_NEW-0015.ckpt.index		      cp_NEW-0066.ckpt.index
# cp_NEW-0016.ckpt.data-00000-of-00001  cp_NEW-0067.ckpt.data-00000-of-00001
# cp_NEW-0016.ckpt.index		      cp_NEW-0067.ckpt.index
# cp_NEW-0017.ckpt.data-00000-of-00001  cp_NEW-0068.ckpt.data-00000-of-00001
# cp_NEW-0017.ckpt.index		      cp_NEW-0068.ckpt.index
# cp_NEW-0018.ckpt.data-00000-of-00001  cp_NEW-0069.ckpt.data-00000-of-00001
# cp_NEW-0018.ckpt.index		      cp_NEW-0069.ckpt.index
# cp_NEW-0019.ckpt.data-00000-of-00001  cp_NEW-0070.ckpt.data-00000-of-00001
# cp_NEW-0019.ckpt.index		      cp_NEW-0070.ckpt.index
# cp_NEW-0020.ckpt.data-00000-of-00001  cp_NEW-0071.ckpt.data-00000-of-00001
# cp_NEW-0020.ckpt.index		      cp_NEW-0071.ckpt.index
# cp_NEW-0021.ckpt.data-00000-of-00001  cp_NEW-0072.ckpt.data-00000-of-00001
# cp_NEW-0021.ckpt.index		      cp_NEW-0072.ckpt.index
# cp_NEW-0022.ckpt.data-00000-of-00001  cp_NEW-0073.ckpt.data-00000-of-00001
# cp_NEW-0022.ckpt.index		      cp_NEW-0073.ckpt.index
# cp_NEW-0023.ckpt.data-00000-of-00001  cp_NEW-0074.ckpt.data-00000-of-00001
# cp_NEW-0023.ckpt.index		      cp_NEW-0074.ckpt.index
# cp_NEW-0024.ckpt.data-00000-of-00001  cp_NEW-0075.ckpt.data-00000-of-00001
# cp_NEW-0024.ckpt.index		      cp_NEW-0075.ckpt.index
# cp_NEW-0025.ckpt.data-00000-of-00001  cp_NEW-0076.ckpt.data-00000-of-00001
# cp_NEW-0025.ckpt.index		      cp_NEW-0076.ckpt.index
# cp_NEW-0026.ckpt.data-00000-of-00001  cp_NEW-0077.ckpt.data-00000-of-00001
# cp_NEW-0026.ckpt.index		      cp_NEW-0077.ckpt.index
# cp_NEW-0027.ckpt.data-00000-of-00001  cp_NEW-0078.ckpt.data-00000-of-00001
# cp_NEW-0027.ckpt.index		      cp_NEW-0078.ckpt.index
# cp_NEW-0028.ckpt.data-00000-of-00001  cp_NEW-0079.ckpt.data-00000-of-00001
# cp_NEW-0028.ckpt.index		      cp_NEW-0079.ckpt.index
# cp_NEW-0029.ckpt.data-00000-of-00001  cp_NEW-0080.ckpt.data-00000-of-00001
# cp_NEW-0029.ckpt.index		      cp_NEW-0080.ckpt.index
# cp_NEW-0030.ckpt.data-00000-of-00001  cp_NEW-0081.ckpt.data-00000-of-00001
# cp_NEW-0030.ckpt.index		      cp_NEW-0081.ckpt.index
# cp_NEW-0031.ckpt.data-00000-of-00001  cp_NEW-0082.ckpt.data-00000-of-00001
# cp_NEW-0031.ckpt.index		      cp_NEW-0082.ckpt.index
# cp_NEW-0032.ckpt.data-00000-of-00001  cp_NEW-0083.ckpt.data-00000-of-00001
# cp_NEW-0032.ckpt.index		      cp_NEW-0083.ckpt.index
# cp_NEW-0033.ckpt.data-00000-of-00001  cp_NEW-0084.ckpt.data-00000-of-00001
# cp_NEW-0033.ckpt.index		      cp_NEW-0084.ckpt.index
# cp_NEW-0034.ckpt.data-00000-of-00001  cp_NEW-0085.ckpt.data-00000-of-00001
# cp_NEW-0034.ckpt.index		      cp_NEW-0085.ckpt.index
# cp_NEW-0035.ckpt.data-00000-of-00001  cp_NEW-0086.ckpt.data-00000-of-00001
# cp_NEW-0035.ckpt.index		      cp_NEW-0086.ckpt.index
# cp_NEW-0036.ckpt.data-00000-of-00001  cp_NEW-0087.ckpt.data-00000-of-00001
# cp_NEW-0036.ckpt.index		      cp_NEW-0087.ckpt.index
# cp_NEW-0037.ckpt.data-00000-of-00001  cp_NEW-0088.ckpt.data-00000-of-00001
# cp_NEW-0037.ckpt.index		      cp_NEW-0088.ckpt.index
# cp_NEW-0038.ckpt.data-00000-of-00001  cp_NEW-0089.ckpt.data-00000-of-00001
# cp_NEW-0038.ckpt.index		      cp_NEW-0089.ckpt.index
# cp_NEW-0039.ckpt.data-00000-of-00001  cp_NEW-0090.ckpt.data-00000-of-00001
# cp_NEW-0039.ckpt.index		      cp_NEW-0090.ckpt.index
# cp_NEW-0040.ckpt.data-00000-of-00001  cp_NEW-0091.ckpt.data-00000-of-00001
# cp_NEW-0040.ckpt.index		      cp_NEW-0091.ckpt.index
# cp_NEW-0041.ckpt.data-00000-of-00001  cp_NEW-0092.ckpt.data-00000-of-00001
# cp_NEW-0041.ckpt.index		      cp_NEW-0092.ckpt.index
# cp_NEW-0042.ckpt.data-00000-of-00001  cp_NEW-0093.ckpt.data-00000-of-00001
# cp_NEW-0042.ckpt.index		      cp_NEW-0093.ckpt.index
# cp_NEW-0043.ckpt.data-00000-of-00001  cp_NEW-0094.ckpt.data-00000-of-00001
# cp_NEW-0043.ckpt.index		      cp_NEW-0094.ckpt.index
# cp_NEW-0044.ckpt.data-00000-of-00001  cp_NEW-0095.ckpt.data-00000-of-00001
# cp_NEW-0044.ckpt.index		      cp_NEW-0095.ckpt.index
# cp_NEW-0045.ckpt.data-00000-of-00001  cp_NEW-0096.ckpt.data-00000-of-00001
# cp_NEW-0045.ckpt.index		      cp_NEW-0096.ckpt.index
# cp_NEW-0046.ckpt.data-00000-of-00001  cp_NEW-0097.ckpt.data-00000-of-00001
# cp_NEW-0046.ckpt.index		      cp_NEW-0097.ckpt.index
# cp_NEW-0047.ckpt.data-00000-of-00001  cp_NEW-0098.ckpt.data-00000-of-00001
# cp_NEW-0047.ckpt.index		      cp_NEW-0098.ckpt.index
# cp_NEW-0048.ckpt.data-00000-of-00001  cp_NEW-0099.ckpt.data-00000-of-00001
# cp_NEW-0048.ckpt.index		      cp_NEW-0099.ckpt.index
# cp_NEW-0049.ckpt.data-00000-of-00001  cp_NEW-0100.ckpt.data-00000-of-00001
# cp_NEW-0049.ckpt.index		      cp_NEW-0100.ckpt.index
# cp_NEW-0050.ckpt.data-00000-of-00001
# './output/cp_NEW-0100.ckpt'

# %% [markdown]
# **Load a Trained Model**

# %%
chk_path= './output/cp_NEW-0080.ckpt'
# Load the previously saved weights
model.load_weights(chk_path)

# %% [markdown]
# **Plot Training and Testing Graphs**

# %%
plot.plot(trained.history['accuracy'])
plot.plot(trained.history['val_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %% [markdown]
# To evaluate a model, there are many methods are proposed to evaluate the model. I use Accuracy to evaluate the performance of my model.

# %%
test_images,test_labels = get_images('/content/drive/MyDrive/Radiology_workshop_monjoy/classification/test_data/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images,test_labels, verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 2.5946e-07 - accuracy: 1.0000
# [2.5945678316929843e-07, 1.0]

# %% [markdown]
# Lets predict the images from the "pred" folder.

# %%
y_pred = model.predict(test_images)
y_pred= y_pred.round()
#y_pred

# %%
len(test_labels)
# Out:
# 21

# %% [markdown]
# **Generate a classification report**

# %%
from sklearn.metrics import classification_report
report = classification_report(test_labels, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %% [markdown]
# **Plot Prediction Results**

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(21):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(test_images))
    pred_image = np.array([test_images[i]])
    pred_prob = model.predict(pred_image)[0]
    #print(pred_prob)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            if pred_prob <0.5:
               ax.set_title('Normal')
            else:
               ax.set_title('COVID-19')
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
fig.show()

# %%
pred_class
# Out:
# 'Normal'

# %% [markdown]
# I hope you like my kernel. Feel free to ask any question in the comment section. I am looking forward for your **sugestions**!
